# %% [markdown]
# ***
# <h1 id="heading"><center><span style="background-color:#5642C5; color:white ; display:fill;border-radius:5px; font-family:cursive"> 5.⚖️Model comparison and model selection✅  </span></center><a class="anchor-link"></a></h1>
# <p><center style="color:#159364; font-family:cursive;">The best way to make yourself extremely valuable in a team is to understand everything, but being a master of something.</center></p>
#
# ***

# %%
MLFLOW_TRACKING_URI = '../models/mlruns'
MLFLOW_EXPERIMENT_NAME = "fake_news_predection"

# %% [markdown]
# ***
# <h3 id="heading"><span style="background-color:#cefffb; color:#1b4946 ; display:fill;border-radius:5px; font-family:cursive"> 📥 Import packages & data </span></h3>

# %%
import mlflow
from mlflow.tracking import MlflowClient

import pandas as pd

# %% [markdown]
# ***
# <h3 id="heading"><span style="background-color:#cefffb; color:#1b4946 ; display:fill;border-radius:5px; font-family:cursive"> 🗄️ Initialize </span></h3>

# %%
# Initialize client
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
client = MlflowClient()

# %% [markdown]
# <h5 id="heading"><span style="background-color:#000639; color:#F6FEFF ; display:fill;border-radius:6px; font-family:Georgia"><Strong>🔵  Get the experiement </Strong></span></h5>

# %%
# Get experiment
experiment = client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
experiment
# Out:
# <Experiment: artifact_location='/home/saitama/project_portfolio/fake_news_classification/notebooks/../models/mlruns/508549783073134129', creation_time=1693854182473, experiment_id='508549783073134129', last_update_time=1693854182473, lifecycle_stage='active', name='fake_news_predection', tags={}>

# %% [markdown]
# ~~~
# cv=CountVectorizer(ngram_range=(1,3),max_features=7000)
# xtrain=cv.fit_transform(xtrain)
# xval=cv.transform(xval)
# ~~~

# %% [markdown]
# <h3 id="heading"><span font-family:Georgia"><Strong>📑 Run model comparaison MLflow </Strong></span></h3>

# %%
# Get all runs
runs = mlflow.search_runs([experiment.experiment_id])
runs
# Out:
#                               run_id       experiment_id    status  \
# 0   a5398e601beb4561bf2150d523639131  508549783073134129  FINISHED
# 1   94e991917a3e4b0bb61860650c449a9d  508549783073134129  FINISHED
# 2   450c7ae83bca4e41b1bbf980add8246f  508549783073134129  FINISHED
# 3   7e55d9a65625406c8c017cacfbb35805  508549783073134129  FINISHED
# 4   9358bf454a0541d48a5cd718aac6ac59  508549783073134129  FINISHED
# 5   063605f3875946e69e2189633f508218  508549783073134129  FINISHED
# 6   9da3c8cebf9547a98df40c3d668def93  508549783073134129  FINISHED
# 7   75e2d19f62b04c39aaa9f338ad6d4524  508549783073134129  FINISHED
# 8   811783d950634146a2583b79e1475c6e  508549783073134129  FINISHED
# 9   42ce63c52a1f4dd7b985c3669f0a9c73  508549783073134129  FINISHED
# 10  f11fb39ff3d54c6a9f821f37e5aba9e7  508549783073134129  FINISHED
# 11  8565ecb6a8da4e36a324876d23615155  508549783073134129  FINISHED
# 12  8cc34fe19c8c4f9abecf5a7e5adf9b20  508549783073134129  FINISHED
# 13  1eace006756c4ea79f2bcb1a19c58b70  508549783073134129    FAILED
#
#                                          artifact_uri  \
# 0   /home/saitama/project_portfolio/fake_news_clas...
# 1   /home/saitama/project_portfolio/fake_news_clas...
# 2   /home/saitama/project_portfolio/fake_news_clas...
# 3   /home/saitama/project_portfolio/fake_news_clas...
# 4   /home/saitama/project_portfolio/fake_news_clas...
# 5   /home/saitama/project_portfolio/fake_news_clas...
# 6   /home/saitama/project_portfolio/fake_news_clas...
# 7   /home/saitama/project_portfolio/fake_news_clas...
# 8   /home/saitama/project_portfolio/fake_news_clas...
# 9   /home/saitama/project_portfolio/fake_news_clas...
# 10  /home/saitama/project_portfolio/fake_news_clas...
# 11  /home/saitama/project_portfolio/fake_news_clas...
# 12  /home/saitama/project_portfolio/fake_news_clas...
# 13  /home/saitama/project_portfolio/fake_news_clas...
#
#                          start_time                         end_time  \
# 0  2023-09-05 09:21:07.624000+00:00 2023-09-05 09:21:07.677000+00:00
# 1  2023-09-05 09:19:26.449000+00:00 2023-09-05 09:19:26.504000+00:00
# 2  2023-09-05 09:18:47.749000+00:00 2023-09-05 09:18:47.838000+00:00
# 3  2023-09-05 09:17:38.043000+00:00 2023-09-05 09:17:38.111000+00:00
# 4  2023-09-05 09:00:36.511000+00:00 2023-09-05 09:00:36.556000+00:00
# 5  2023-09-05 08:51:08.716000+00:00 2023-09-05 08:51:08.786000+00:00
# 6  2023-09-05 08:47:28.343000+00:00 2023-09-05 08:47:28.411000+00:00
# 7  2023-09-05 08:37:43.208000+00:00 2023-09-05 08:37:43.278000+00:00
# 8  2023-09-05 08:36:03.884000+00:00 2023-09-05 08:36:03.945000+00:00
# 9  2023-09-05 08:35:24.981000+00:00 2023-09-05 08:35:25.047000+00:00
# 10 2023-09-05 08:34:15.889000+00:00 2023-09-05 08:34:16.001000+00:00
# 11 2023-09-05 08:16:44.739000+00:00 2023-09-05 08:16:44.818000+00:00
# 12 2023-09-04 22:19:43.692000+00:00 2023-09-04 22:19:43.750000+00:00
# 13 2023-09-04 22:17:47.569000+00:00 2023-09-04 22:17:47.612000+00:00
#
#     metrics.recall_score  metrics.f1_score  metrics.accuracy_score  \
# 0                  62.74             65.59                   63.79
# 1                  62.60             65.60                   63.88
# 2                  62.01             66.98                   66.37
# 3                  62.43             65.30                   63.50
# 4                  62.43             65.13                   63.23
# 5                  62.74             65.59                   63.79
# 6                    NaN               NaN                     NaN
# 7                    NaN               NaN                     NaN
# 8                    NaN               NaN                     NaN
# 9                    NaN               NaN                     NaN
# 10                   NaN               NaN                     NaN
# 11                   NaN               NaN                     NaN
# 12                   NaN               NaN                     NaN
# 13                   NaN               NaN                     NaN
#
#     metrics.precision_score  metrics.Validation Score tags.mlflow.source.type  \
# 0                     68.72                       NaN                   LOCAL
# 1                     68.91                       NaN                   LOCAL
# 2                     72.82                       NaN                   LOCAL
# 3                     68.46                       NaN                   LOCAL
# 4                     68.09                       NaN                   LOCAL
# 5                     68.72                       NaN                   LOCAL
# 6                       NaN                   65.2100                   LOCAL
# 7                       NaN                   65.2100                   LOCAL
# 8                       NaN                   65.1375                   LOCAL
# 9                       NaN                   67.0225                   LOCAL
# 10                      NaN                   64.9225                   LOCAL
# 11                      NaN                   64.7200                   LOCAL
# 12                      NaN                   64.7200                   LOCAL
# 13                      NaN                       NaN                   LOCAL
#
#                               tags.mlflow.source.name  \
# 0   /home/saitama/.local/lib/python3.11/site-packa...
# 1   /home/saitama/.local/lib/python3.11/site-packa...
# 2   /home/saitama/.local/lib/python3.11/site-packa...
# 3   /home/saitama/.local/lib/python3.11/site-packa...
# 4   /home/saitama/.local/lib/python3.11/site-packa...
# 5   /home/saitama/.local/lib/python3.11/site-packa...
# 6   /home/saitama/.local/lib/python3.11/site-packa...
# 7   /home/saitama/.local/lib/python3.11/site-packa...
# 8   /home/saitama/.local/lib/python3.11/site-packa...
# 9   /home/saitama/.local/lib/python3.11/site-packa...
# 10  /home/saitama/.local/lib/python3.11/site-packa...
# 11  /home/saitama/.local/lib/python3.11/site-packa...
# 12  /home/saitama/.local/lib/python3.11/site-packa...
# 13  /home/saitama/.local/lib/python3.11/site-packa...
#
#                      tags.mlflow.runName tags.mlflow.user
# 0                    XGboost Classifier           saitama
# 1              Decision Tree Classifier           saitama
# 2              random Forest Classifier           saitama
# 3       Support Vector Classifier (SVM)           saitama
# 4   Baseline model: Logistic Regression           saitama
# 5                    XGboost Classifier           saitama
# 6                    XGboost Classifier           saitama
# 7                    XGboost Classifier           saitama
# 8              Decision Tree Classifier           saitama
# 9              random Forest Classifier           saitama
# 10      Support Vector Classifier (SVM)           saitama
# 11  Baseline model: Logistic Regression           saitama
# 12  Baseline model: Logistic Regression           saitama
# 13  Baseline model: Logistic Regression           saitama
